# %% [markdown]
# ### Randomizing an adjacency
#
# Algorithms to randomize an adjacency matrix of a binary undirected network preserving each node degree.

# %%
# %matplotlib inline
import ctypes
import numpy             as np
import numba             as nb
import matplotlib.pyplot as plt
from   tqdm              import tqdm

# %%
_ra = ctypes.CDLL('./libradj.so')

# %%
_ra.randomize_adjacency.argtypes = (ctypes.c_int, ctypes.c_int, ctypes.c_int, 
                                    ctypes.POINTER(ctypes.POINTER(ctypes.c_int)), 
                                    ctypes.POINTER(ctypes.c_int), ctypes.POINTER(ctypes.c_int), ctypes.c_int)
_ra.randomize_adjacency.restype  = ctypes.POINTER(ctypes.POINTER(ctypes.c_int))

# %% [markdown]
# ### Defining wrapper for C function in python

# %%
def randomize_adjacency(A, n_rewires, seed):
    global _ra
    A_copy = np.array(A, dtype=np.int32).copy()
    # Number of nodes
    n_nodes = A_copy.shape[0]
    # Getting edges
    i,j   = np.tril_indices_from(A_copy, k=-1)
    w     = A_copy[i,j]
    edges = np.array([j,i]).T
    i,j   = edges[w.astype(bool),:].T
    # Number of edges
    n_edges = len(i)
    
    #
    UI8Ptr = ctypes.POINTER(ctypes.c_int)
    UI8PtrPtr = ctypes.POINTER(UI8Ptr)

    ct_arr = np.ctypeslib.as_ctypes(A_copy)
    UI8PtrArr = UI8Ptr * ct_arr._length_
    ct_ptr = ctypes.cast(UI8PtrArr(*(ctypes.cast(row, UI8Ptr) for row in ct_arr)), UI8PtrPtr)

    
    array_type  = (ctypes.c_int * n_edges)
    
    # Call function
    Arn = _ra.randomize_adjacency(ctypes.c_int(n_rewires), ctypes.c_int(n_nodes), ctypes.c_int(n_edges), \
                                  ct_ptr, array_type(*i), array_type(*j), ctypes.c_int(seed))
    
    Arn_py = np.array([[Arn[i][j] for j in range(n_nodes)] for i in range(n_nodes)], dtype=Arn._type_._type_._type_)
    return Arn_py

# %% [markdown]
# ### Python implementation

# %%
def randomize_adjacency_py(A, n_rewires,seed):
    np.random.seed(seed)
    A_copy  = A.copy()
    # Number of nodes
    n_nodes = A_copy.shape[0]
    # Getting edges
    i,j   = np.tril_indices_from(A_copy, k=-1)
    w     = A_copy[i,j]
    edges = np.array([j,i]).T
    i,j   = edges[w.astype(bool),:].T
    # Number of edges
    n_edges = len(i)
    # Iterating over n_rewires
    n = 0
    while(n<n_rewires):
        e1, e2 = np.random.choice(range(n_edges), size=2, replace = False)
        a = i[e1]
        b = j[e1]
        c = i[e2]
        d = j[e2]
        if (A_copy[a,d]==0 and A_copy[c,b]==0 and a!=d and a!=c and c!=b and b!=d):
            j[e1] = d
            i[e2] = b
            j[e2] = c
            
            A_copy[a,b] = 0
            A_copy[b,a] = 0
            A_copy[c,d] = 0
            A_copy[d,c] = 0
            A_copy[a,d] = 1
            A_copy[d,a] = 1
            A_copy[c,b] = 1
            A_copy[b,c] = 1
            n+=1
        else:
            continue
    return A_copy

# %% [markdown]
# #### Load an adjacency matrix

# %%
A = np.loadtxt('adj.txt',delimiter=' ', dtype=int)

# %% [markdown]
# #### C

# %%
Arn = randomize_adjacency(A, int(111 * np.log(1/1e-7)), 0)

# %% [markdown]
# #### Python

# %%
Arn_py = randomize_adjacency_py(A, int(111 * np.log(1/1e-7)), 0)

# %%
plt.figure(figsize=(15,4))
plt.subplot(1,3,1)
plt.imshow(A,aspect='auto',cmap='gray', origin = 'lower')
plt.title('Original')
plt.xticks([])
plt.yticks([])
plt.subplot(1,3,2)
plt.imshow(Arn,aspect='auto',cmap='gray', origin = 'lower')
plt.title('C randomized')
plt.xticks([])
plt.yticks([])
plt.subplot(1,3,3)
plt.imshow(Arn_py,aspect='auto',cmap='gray', origin = 'lower')
plt.title('Python randomized')
plt.xticks([])
plt.yticks([])
# Out:
# ([], [])

# %% [markdown]
# #### Check if the degrees were preserved

# %%
d_o = A.sum(axis = 1)
d_c = Arn.sum(axis = 1)
d_p = Arn_py.sum(axis = 1)

# %%
plt.plot(d_o, label = 'original')
plt.plot(d_c, 'r--', label = 'C randomized')
plt.plot(d_p, 'gs', label = 'Python randomized')
plt.xlabel('Node index')
plt.ylabel('Degree')
plt.legend()
plt.tight_layout()

# %% [markdown]
# ### Comparing perfomance between Python, C and igraph

# %%
import igraph   as ig
import networkx as nx

# %%
def instantiate_igraph(A):
    #n_nodes = A.shape[0]
    # Getting edges
    #i,j   = np.tril_indices_from(A, k=-1)
    #w     = A[i,j]
    #edges = np.array([j,i]).T
    #i,j   = edges[w.astype(bool),:].T
    g = nx.Graph(A)
    return ig.Graph(A.shape[0],g.edges)  #ig.Graph(n_nodes, zip(i,j))

# %%
n_rewires = np.arange(10, 111 * np.log(1/1e-8), 100, dtype=int)
ex_t      = np.zeros([3,2,len(n_rewires)])
g         = instantiate_igraph(A)

# %%
for i in range(n_rewires.shape[0]):
    t1 = %timeit -o randomize_adjacency(A, n_rewires[i], 0)
    ex_t[0,0,i]=t1.average
    ex_t[0,1,i]=t1.stdev
    t2 = %timeit -o randomize_adjacency_py(A, n_rewires[i], 0)
    ex_t[1,0,i]=t2.average
    ex_t[1,1,i]=t2.stdev
    t3 = %timeit -o g.rewire(n_rewires[i])
    ex_t[2,0,i]=t3.average
    ex_t[2,1,i]=t3.stdev
# Out:
# 1.61 ms ± 13.7 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 1.14 ms ± 96.6 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 43.8 µs ± 2.77 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 2.09 ms ± 147 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 9.26 ms ± 366 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 115 µs ± 8.39 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 2.1 ms ± 263 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 17.4 ms ± 174 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 177 µs ± 2.14 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 1.77 ms ± 115 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 25.6 ms ± 236 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 261 µs ± 32.9 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 2.36 ms ± 224 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 35.5 ms ± 2.41 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 315 µs ± 25.5 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 2.6 ms ± 381 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 43.9 ms ± 2.24 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 404 µs ± 42.6 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 2.6 ms ± 120 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 50.9 ms ± 630 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 448 µs ± 20.5 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 3.31 ms ± 400 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 62.7 ms ± 1.86 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 555 µs ± 58.3 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 3 ms ± 654 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 74.7 ms ± 7.05 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 602 µs ± 51.7 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 3.04 ms ± 112 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 80.7 ms ± 4.1 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 645 µs ± 26.7 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 3.6 ms ± 251 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 90.8 ms ± 3.87 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 411 µs ± 175 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 2.17 ms ± 67.1 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 82.6 ms ± 4.67 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 702 µs ± 15.7 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 2.38 ms ± 134 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 92.7 ms ± 1.29 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 759 µs ± 15.7 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 2.43 ms ± 113 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 102 ms ± 1.39 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 825 µs ± 15.6 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 2.64 ms ± 168 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 107 ms ± 7.67 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 873 µs ± 14.1 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 2.89 ms ± 184 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 116 ms ± 2.06 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 942 µs ± 10.9 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 2.73 ms ± 139 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 121 ms ± 5.89 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 1 ms ± 11.8 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 3 ms ± 248 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 133 ms ± 2.23 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 1.05 ms ± 19.6 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 3.21 ms ± 227 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 138 ms ± 4.27 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 1.12 ms ± 11.4 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 3.18 ms ± 173 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 149 ms ± 1.66 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 1.17 ms ± 13.7 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 3.4 ms ± 167 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 152 ms ± 5.33 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 1.24 ms ± 18.8 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
plt.plot(n_rewires, ex_t[0,0], 's-b', label = 'C')
plt.fill_between(n_rewires, ex_t[0,0]-ex_t[0,1], ex_t[0,0]+ex_t[0,1], color='b', alpha = .2)
#
plt.plot(n_rewires, ex_t[1,0], 'r-s', label = 'Python')
plt.fill_between(n_rewires, ex_t[1,0]-ex_t[1,1], ex_t[1,0]+ex_t[1,1], color='r', alpha = .2)
#
plt.plot(n_rewires, ex_t[2,0], 's-m', label = 'igraph')
plt.fill_between(n_rewires, ex_t[2,0]-ex_t[2,1], ex_t[2,0]+ex_t[2,1], color='b', alpha = .2)
plt.xlabel(r'$n_{\rm rewires}$')
plt.ylabel('time [ms]')
plt.legend()

# %%
plt.plot(n_rewires, ex_t[0,0], 's-b', label = 'C')
plt.fill_between(n_rewires, ex_t[0,0]-ex_t[0,1], ex_t[0,0]+ex_t[0,1], color='b', alpha = .2)
#
plt.plot(n_rewires, ex_t[2,0], 's-m', label = 'igraph')
plt.fill_between(n_rewires, ex_t[2,0]-ex_t[2,1], ex_t[2,0]+ex_t[2,1], color='b', alpha = .2)
plt.legend()
plt.xlabel(r'$n_{\rm rewires}$')
plt.ylabel('time [ms]')
plt.legend()
