# %% [markdown]
# ### Randomizing an adjacency
#
# Algorithms to randomize an adjacency matrix of a binary undirected network preserving each node degree.

# %%
# %matplotlib inline
import ctypes
import numpy             as np
import numba             as nb
import matplotlib.pyplot as plt
from   tqdm              import tqdm

# %%
_ra = ctypes.CDLL('./libwadj.so')

# %%
_ra.randomize_adjacency_wei.argtypes = (ctypes.c_int, ctypes.c_int, 
                                        ctypes.POINTER(ctypes.POINTER(ctypes.c_float)), 
                                        ctypes.POINTER(ctypes.c_int))
_ra.randomize_adjacency_wei.restype  = ctypes.POINTER(ctypes.POINTER(ctypes.c_float))

# %% [markdown]
# ### Defining wrapper for C function in python

# %%
def randomize_adjacency_wei(A, n_rewires, seed):
    global _ra
    A_copy = np.array(A, dtype=float).copy()
    # Number of nodes
    n_nodes = A_copy.shape[0]
    # Getting edges
    i,j   = np.tril_indices_from(A_copy, k=-1)
    w     = A_copy[i,j]
    edges = np.array([j,i]).T
    i,j   = edges[w.astype(bool),:].T
    # Number of edges
    n_edges = len(i)
    
    #
    UI8Ptr    = ctypes.POINTER(ctypes.c_float)
    UI8PtrPtr = ctypes.POINTER(UI8Ptr)

    ct_arr    = np.ctypeslib.as_ctypes(A_copy)
    UI8PtrArr = UI8Ptr * ct_arr._length_
    ct_ptr    = ctypes.cast(UI8PtrArr(*(ctypes.cast(row, UI8Ptr) for row in ct_arr)), UI8PtrPtr)

    
    array_type  = (ctypes.c_int * n_edges)
    
    # Call function
    Arn = _ra.randomize_adjacency_wei(ctypes.c_int(n_rewires), ctypes.c_int(n_nodes), \
                                  ct_ptr, ctypes.c_int(seed))
    
    Arn_py = np.array([[Arn[i][j] for j in range(n_nodes)] for i in range(n_nodes)], dtype=Arn._type_._type_._type_)
    return Arn_py

# %% [markdown]
# ### Python implementation

# %%
def _randomize_adjacency_wei(A, n_swaps, seed):
    
    np.random.seed(seed)
    
    # Number of nodes
    n_nodes = A.shape[0]
    # Copy the adj. matrix
    A_rnd   = A.copy()
    
    # Choose edges that will be swaped
    i,j,k,l = np.random.choice(n_nodes, size=(4, n_swaps), replace=True)
    
    #itr = range(n_swaps)
    #for it in tqdm(itr) if verbose else itr:
    for it in range(n_swaps):
        if len( np.unique([1,2,3,4]) ) < 4:
            print('oi')
            continue
        else:
            # Swaping edges
            A_rnd[i,l]=A_rnd[l,i]=A[i,j]
            A_rnd[i,j]=A_rnd[j,i]=A[i,l]
            A_rnd[k,j]=A_rnd[j,k]=A[k,l]
            A_rnd[l,k]=A_rnd[k,l]=A[k,j]
    return A_rnd

# %% [markdown]
# #### Load an adjacency matrix

# %%
A = np.loadtxt('adj.txt',delimiter=' ', dtype=int)

# %%
A = A * np.random.randint(0,2,A.shape)
A = (A+A.T)/2
np.fill_diagonal(A,1)

# %% [markdown]
# #### C

# %%
Arn = randomize_adjacency_wei(A, 1000, 0)

# %% [markdown]
# #### Python

# %%
Arn_py = _randomize_adjacency_wei(A, 1000, 0)

# %%
plt.figure(figsize=(20,6))
plt.subplot(1,3,1)
plt.imshow(A,aspect='auto',cmap='viridis', origin = 'lower')
plt.title('Original')
plt.xticks([])
plt.yticks([])
plt.subplot(1,3,2)
plt.imshow(Arn,aspect='auto',cmap='viridis', origin = 'lower')
plt.title('C randomized')
plt.xticks([])
plt.yticks([])
plt.subplot(1,3,3)
plt.imshow(Arn_py,aspect='auto',cmap='viridis', origin = 'lower')
plt.title('Python randomized')
plt.xticks([])
plt.yticks([]);

# %% [markdown]
# #### Check if the degrees were preserved

# %%
d_o = A.sum(axis = 1)
d_c = Arn.sum(axis = 1)
d_p = Arn_py.sum(axis = 1)

# %%
plt.plot(d_o, label = 'original')
plt.plot(d_c, 'r--', label = 'C randomized')
plt.plot(d_p, 'gs', label = 'Python randomized')
plt.xlabel('Node index')
plt.ylabel('Degree')
plt.legend()
plt.tight_layout()

# %% [markdown]
# ### Comparing perfomance between Python, C and igraph

# %%
import igraph   as ig
import networkx as nx

# %%
def instantiate_igraph(A):
    #n_nodes = A.shape[0]
    # Getting edges
    #i,j   = np.tril_indices_from(A, k=-1)
    #w     = A[i,j]
    #edges = np.array([j,i]).T
    #i,j   = edges[w.astype(bool),:].T
    g = nx.Graph(A)
    return ig.Graph(A.shape[0],g.edges)  #ig.Graph(n_nodes, zip(i,j))

# %%
n_rewires = np.arange(10, 111 * np.log(1/1e-8), 100, dtype=int)
ex_t      = np.zeros([2,2,len(n_rewires)])
g         = instantiate_igraph(A)

# %%
for i in range(n_rewires.shape[0]):
    t1 = %timeit -o randomize_adjacency_wei(A, n_rewires[i], 0)
    ex_t[0,0,i]=t1.average
    ex_t[0,1,i]=t1.stdev
    t2 = %timeit -o _randomize_adjacency_wei(A, n_rewires[i], 0)
    ex_t[1,0,i]=t2.average
    ex_t[1,1,i]=t2.stdev
# Out:
# 559 µs ± 8.15 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 104 µs ± 836 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 795 µs ± 14.1 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 1.45 ms ± 51.2 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 964 µs ± 6.02 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 3.6 ms ± 32 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 1.17 ms ± 11.7 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 6.6 ms ± 38.2 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 1.38 ms ± 9.43 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 10.4 ms ± 39.3 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 1.55 ms ± 10.3 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 15.2 ms ± 46.9 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 1.73 ms ± 9.28 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 20.8 ms ± 197 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 1.93 ms ± 18.1 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 27.1 ms ± 480 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 2.15 ms ± 61 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 34.3 ms ± 262 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 2.36 ms ± 64.3 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 42.6 ms ± 364 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 2.55 ms ± 57.3 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 51.4 ms ± 463 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 2.83 ms ± 40.4 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 61.8 ms ± 454 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 3 ms ± 79.1 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 71.6 ms ± 343 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 3.14 ms ± 39.3 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 83.3 ms ± 451 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 3.42 ms ± 75.7 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 96 ms ± 856 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 3.59 ms ± 69.2 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 109 ms ± 660 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 3.8 ms ± 68.3 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 122 ms ± 853 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 4.05 ms ± 88.5 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 137 ms ± 750 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 4.2 ms ± 31.2 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 152 ms ± 824 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 4.44 ms ± 78.9 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 169 ms ± 1.24 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 4.71 ms ± 114 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 187 ms ± 1.12 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
plt.plot(n_rewires, ex_t[0,0], 's-b', label = 'C')
plt.fill_between(n_rewires, ex_t[0,0]-ex_t[0,1], ex_t[0,0]+ex_t[0,1], color='b', alpha = .2)
#
plt.plot(n_rewires, ex_t[1,0], 'r-s', label = 'Python')
plt.fill_between(n_rewires, ex_t[1,0]-ex_t[1,1], ex_t[1,0]+ex_t[1,1], color='r', alpha = .2)
#
plt.plot(n_rewires, ex_t[2,0], 's-m', label = 'igraph')
plt.fill_between(n_rewires, ex_t[2,0]-ex_t[2,1], ex_t[2,0]+ex_t[2,1], color='b', alpha = .2)
plt.xlabel(r'$n_{\rm rewires}$')
plt.ylabel('time [ms]')
plt.legend()

# %%
plt.plot(n_rewires, ex_t[0,0], 's-b', label = 'C')
plt.fill_between(n_rewires, ex_t[0,0]-ex_t[0,1], ex_t[0,0]+ex_t[0,1], color='b', alpha = .2)
#
plt.plot(n_rewires, ex_t[2,0], 's-m', label = 'igraph')
plt.fill_between(n_rewires, ex_t[2,0]-ex_t[2,1], ex_t[2,0]+ex_t[2,1], color='b', alpha = .2)
plt.legend()
plt.xlabel(r'$n_{\rm rewires}$')
plt.ylabel('time [ms]')
plt.legend()
