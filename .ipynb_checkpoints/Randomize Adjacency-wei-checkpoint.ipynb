# %% [markdown]
# ### Randomizing an adjacency
#
# Algorithms to randomize an adjacency matrix of a binary undirected network preserving each node degree.
#
# #### For weighed networks, you need to preserve strengths not just degrees, so:
# - Take a random pair of links ij and kl
# - Consider the strengths w_ij, w_kl as well as w_il and w_kj
# - Set w_il to a new value equal to old w_ij and w_ij to a new value equal to old w_il
# - Set w_kj to a new value equal to old w_kl and w_kl to a new value equal to old w_kj
# - Do the same for the pair ji and lk, since the coherence networks must be symmetric

# %%
# %matplotlib inline
import ctypes
import numpy             as np
import numba             as nb
import matplotlib.pyplot as plt
from   tqdm              import tqdm

# %%
_ra = ctypes.CDLL('./libwadj.so')

# %%
_ra.randomize_adjacency_wei.argtypes = (ctypes.c_int, ctypes.c_int, 
                                        ctypes.POINTER(ctypes.POINTER(ctypes.c_float)), 
                                        ctypes.POINTER(ctypes.c_int))
_ra.randomize_adjacency_wei.restype  = ctypes.POINTER(ctypes.POINTER(ctypes.c_float))

# %% [markdown]
# ### Defining wrapper for C function in python

# %%
def randomize_adjacency_wei(A, n_rewires, seed):
    global _ra
    A_copy  = np.array(A, dtype=np.float32).copy()
    # Number of nodes
    n_nodes = A_copy.shape[0]
    # Getting edges with connection
    x_s,x_t = np.tril_indices_from(A_copy, k=-1)
    w       = A_copy[x_s,x_t]
    non_zero= np.where(w>0)
    x_s,x_t = x_s[non_zero],x_t[non_zero]
    # Number of edges
    n_edges = len(x_s)
    
    # To convert array with sources and targets
    array_type  = (ctypes.c_int * n_edges)
    
    # Converting matrix to pointer to pointer
    UF32Ptr    = ctypes.POINTER(ctypes.c_float)
    UF32PtrPtr = ctypes.POINTER(UF32Ptr)

    ct_arr     = np.ctypeslib.as_ctypes(A_copy)
    UF32PtrArr = UF32Ptr * ct_arr._length_
    ct_ptr_A   = ctypes.cast(UF32PtrArr(*(ctypes.cast(row, UF32Ptr) for row in ct_arr)), UF32PtrPtr)
    
    # Call function
    Arn = _ra.randomize_adjacency_wei(ctypes.c_int(n_rewires), ctypes.c_int(n_nodes), ct_ptr_A, ctypes.c_int(seed))
    
    Arn_py = np.array([[Arn[i][j] for j in range(n_nodes)] for i in range(n_nodes)], dtype=Arn._type_._type_._type_)
    return Arn_py

# %% [markdown]
# ### Python implementation

# %%
def _randomize_adjacency_wei(A, n_swaps, seed):
    
    np.random.seed(seed)
    
    # Number of nodes
    n_nodes = A.shape[0]
    # Copy the adj. matrix
    Arnd    = A.copy()
    
    # Choose edges that will be swaped
    edges = np.random.choice(n_nodes, size=(4, n_swaps), replace=True).T
    
    #itr = range(n_swaps)
    #for it in tqdm(itr) if verbose else itr:
    it = 0
    for it in range(n_swaps):
        #i,j,k,l = edges[it,:]
        i, j, k, l = e = edges[it, :]
        if len(np.unique(e))<4:
            continue
        else:
            # Old values of weigths
            w_ij,w_il,w_kj,w_kl=Arnd[i,j],Arnd[i,l],Arnd[k,j],Arnd[k,l]
            # Swaping edges
            Arnd[i,j]=Arnd[j,i]=w_il
            Arnd[k,l]=Arnd[l,k]=w_kj
            Arnd[i,l]=Arnd[l,i]=w_ij
            Arnd[k,j]=Arnd[j,k]=w_kl
    return Arnd

# Pre-compiled method
_randomize_adjacency_wei_jit = nb.jit(nopython=True)(_randomize_adjacency_wei)

# %% [markdown]
# #### Load an adjacency matrix

# %%
A = np.load("fc.npy") #np.loadtxt('adj.txt',delimiter=' ', dtype=int)

# %%
B = A[np.triu_indices(120,1)]
plt.plot(np.sort(B))

# %%
def shuffle_quartets(i, iw):
    ii = np.zeros_like(i)
    iiw = np.zeros_like(iw)
    for idx in range(i.shape[0]):
        ii[idx,:] = i[idx,:].copy()
        np.random.shuffle( ii[idx,:] )
        ######################################
        iiw[idx,:] = iw[idx,:].copy()
        np.random.shuffle( iiw[idx,:] )
    return ii, iiw

def create_null_model(A, k=4):
    n_nodes = len(A)
    B = A[np.triu_indices(n_nodes,1)]
    sort = np.argsort(B)
    i = np.argsort(B).reshape((-1,k))
    iw = np.sort(B).reshape((-1,k))
    ii, iiw = shuffle_quartets(i, iw)
    
    out = iiw.flatten()[np.argsort(sort)]
    N = np.zeros((n_nodes,n_nodes))
    N[np.triu_indices(n_nodes,1)]=out
    return N+N.T+np.eye(120)

# %%
def shuffle_quartets(i, iw):
    ii = np.zeros_like(i)
    iiw = np.zeros_like(iw)
    for idx in range(i.shape[0]):
        ii[idx,:] = i[idx,:].copy()
        np.random.shuffle( ii[idx,:] )
        ###############################
        iiw[idx,:] = iw[idx,:].copy()
        np.random.shuffle( iiw[idx,:] )
    return ii, iiw

def create_null_model(A, k=4, seed=0):
    
    np.random.seed(seed)
    
    n_nodes = len(A)
    n_edges = int( n_nodes*(n_nodes-1)/2 )
    
    rem = int( (np.arange(n_edges)%k)[-1]+1 )
    
    B = A[np.triu_indices(n_nodes,1)]
    
    sort = np.argsort(B)
    wsort = np.sort(B)
    
    i = sort[rem:].reshape((-1,k))
    iw = wsort[rem:].reshape((-1,k))
    ii, iiw = shuffle_quartets(i, iw)
    
    out = iiw.flatten()[np.argsort(sort[rem:])]
    out = np.hstack((wsort[:rem],out))
    #print(f"{out.shape}")
    N = np.zeros((n_nodes,n_nodes))
    N[np.triu_indices(n_nodes,1)]=out
    return N+N.T+np.eye(120)

# %%
Anull=A.copy()
count=0
for k_v in [30,3]:
    try:
        out = create_null_model(Anull,k=k_v)
    except:
        continue
    Anull=out
    count+=1

# %%
count
# Out:
# 2

# %%
plt.imshow(A, aspect="auto")
plt.colorbar()

# %%
plt.imshow(Anull, aspect="auto")
plt.colorbar()

# %%
import brainconn

# %%
gamma = np.linspace(0.5, 2.0, 30)

# %%
q_o = np.zeros_like(gamma)
q_n = np.zeros((10, len(gamma)))

for j, g in enumerate( gamma ):
    _, q_o[j] = brainconn.modularity.modularity_louvain_und_sign(A, gamma=g)
    for i in range(10): 
        
        Anull=A.copy()
        for k_v in [30,3]: Anull = create_null_model(Anull,k=k_v,seed=i*1000)
            
        _, q_n[i,j] = brainconn.modularity.modularity_louvain_und_sign(Anull, gamma=g)

# %%
plt.plot(gamma, q_o-q_n.mean(0) )

# %%
Arnd = _randomize_adjacency_wei_jit(A, 5000, 0)

# %%
plt.imshow(A, aspect="auto")
plt.colorbar()

# %%
plt.imshow(Arnd, aspect="auto")
plt.colorbar()

# %%
q_o = np.zeros_like(gamma)
q_n = np.zeros((10, len(gamma)))

for j, g in enumerate( gamma ):
    _, q_o[j] = brainconn.modularity.modularity_louvain_und_sign(A, gamma=g)
    for i in range(10): 
        
        Anull=A.copy()
        for k_v in [30,3]: Anull = _randomize_adjacency_wei_jit(Anull,5000,i*1000)
            
        _, q_n[i,j] = brainconn.modularity.modularity_louvain_und_sign(Anull, gamma=g)

# %%
plt.plot(gamma, q_o-q_n.mean(0) )

# %%
plt.plot(np.sort(A.sum(1)))
plt.plot(np.sort(Arnd.sum(1)))

# %% [markdown]
# #### C

# %%
Arn    =  randomize_adjacency_wei(A, 10000,  400)

# %% [markdown]
# #### Python

# %%
Arn_py = _randomize_adjacency_wei(A, 10000, 400)

# %% [markdown]
# #### Python (numba)

# %%
Arn_pyn = _randomize_adjacency_wei_jit(A, 10000, 400)

# %%
plt.figure(figsize=(25,6))
plt.subplot(1,4,1)
plt.imshow(A,aspect='auto',cmap='viridis', origin = 'lower')
plt.title('Original', fontsize=15)
plt.xticks([])
plt.yticks([])
plt.subplot(1,4,2)
plt.imshow(Arn,aspect='auto',cmap='viridis', origin = 'lower')
plt.title('C randomized', fontsize=15)
plt.xticks([])
plt.yticks([])
plt.subplot(1,4,3)
plt.imshow(Arn_py,aspect='auto',cmap='viridis', origin = 'lower')
plt.title('Python randomized', fontsize=15)
plt.xticks([])
plt.yticks([])
plt.subplot(1,4,4)
plt.imshow(Arn_pyn,aspect='auto',cmap='viridis', origin = 'lower')
plt.title('Python (numba) randomized', fontsize=15)
plt.xticks([])
plt.yticks([]);

# %%
# Network average degrees
d1=A.sum(-1)
d2=Arn_py.sum(-1)
d3=Arn_py.sum(-1)
d4=Arn_pyn.sum(-1)
print('Average strength of the network:')
print('---------------------------------------')
print(f'Original                  = {d1.mean()}')
print(f'C randomized              = {d2.mean()}')
print(f'Python randomized         = {d3.mean()}')
print(f'Python (numba) randomized = {d4.mean()}')
# Out:
# Average strength of the network:
# ---------------------------------------
# Original                  = 21.591836734693878
# C randomized              = 21.591836734693878
# Python randomized         = 21.591836734693878
# Python (numba) randomized = 21.591836734693878

# %% [markdown]
# #### Test if average network strength is maintained for different seeds

# %%
n_rewires  = 10000
seeds      = np.linspace(0, 1000,20,dtype=int)
d1, d2, d3, d4 = [],[],[],[]

for seed in tqdm( seeds ):
    d1 += [A.sum(-1).mean()]
    d2 += [randomize_adjacency_wei(A,  n_rewires, seed).sum(-1).mean()]
    d3 += [_randomize_adjacency_wei(A, n_rewires, seed).sum(-1).mean()]
    d4 += [_randomize_adjacency_wei_jit(A, n_rewires, seed).sum(-1).mean()]
d1 = np.squeeze(d1).astype(np.float32)
d2 = np.squeeze(d2).astype(np.float32)
d3 = np.squeeze(d3).astype(np.float32)
d4 = np.squeeze(d4).astype(np.float32)
# Out:
# 100%|██████████| 20/20 [00:01<00:00, 10.86it/s]

# %%
plt.figure(figsize=(12,6))
plt.plot(seeds, d1, label='Avg. strength, original',    marker='o')
plt.plot(seeds, d2, label='Avg. strength, Python rnd.', marker='.')
plt.plot(seeds, d3, label='Avg. strength, C rnd.',      marker='^')
plt.plot(seeds, d4, label='Avg. strength, Python (numba) rnd.', marker='*')
plt.xlim([0,1000])
plt.legend()

# %% [markdown]
# #### Check if the degrees were preserved

# %%
d_o = A.sum(axis = -1)
d_c = Arn.sum(axis = -1)
d_p = Arn_py.sum(axis = -1)
d_pn = Arn_pyn.sum(axis = -1)

# %%
plt.figure(figsize=(12,6))
plt.plot(d_o, label = 'original')
plt.plot(d_c, '--', label = 'C randomized')
plt.plot(d_p, '-.',label = 'Python randomized')
plt.plot(d_pn, 's--',label = 'Python (numba) randomized')
plt.xlabel('Node index', fontsize=15)
plt.ylabel('Strength', fontsize=15)
plt.legend()
plt.tight_layout()

# %%
plt.figure(figsize=(12,6))
plt.plot(d_o[np.argsort(d_o)], label = 'original')
plt.plot(d_c[np.argsort(d_c)], '--', label = 'C randomized')
plt.plot(d_p[np.argsort(d_p)], '-.',label = 'Python randomized')
plt.plot(d_pn[np.argsort(d_pn)], 's--',label = 'Python (numba) randomized')
plt.xlabel('Node index', fontsize=15)
plt.ylabel('Strength', fontsize=15)
plt.legend()
plt.tight_layout()

# %%
plt.figure(figsize=(12,6))
plt.hist(d_o, alpha=.2)
plt.hist(d_p, alpha=.2)
plt.xlabel('Node index', fontsize=15)
plt.ylabel('Strength', fontsize=15)
plt.legend()
plt.tight_layout()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# ### Comparing perfomance between Python, C and igraph

# %%
n_rewires = np.arange(10, 111 * np.log(1/1e-8), 100, dtype=int)
ex_t      = np.zeros([3,2,len(n_rewires)])

# %%
plt.figure(figsize=(12,6))
for i in range(n_rewires.shape[0]):
    t1 = %timeit -o randomize_adjacency_wei(A, n_rewires[i], 0)
    ex_t[0,0,i]=t1.average
    ex_t[0,1,i]=t1.stdev
    t2 = %timeit -o _randomize_adjacency_wei(A, n_rewires[i], 0)
    ex_t[1,0,i]=t2.average
    ex_t[1,1,i]=t2.stdev
    t3 = %timeit -o _randomize_adjacency_wei_jit(A, n_rewires[i], 0)
    ex_t[2,0,i]=t3.average
    ex_t[2,1,i]=t3.stdev
# Out:
# 519 µs ± 10.9 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 97.6 µs ± 1.46 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 14.1 µs ± 503 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)
# 538 µs ± 18.1 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 895 µs ± 16.8 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 127 µs ± 3.26 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 513 µs ± 5.89 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 1.6 ms ± 34.9 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 237 µs ± 2.51 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 521 µs ± 5.61 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 2.33 ms ± 47.5 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 353 µs ± 7.66 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 527 µs ± 2.29 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 3.07 ms ± 27.8 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 464 µs ± 8.36 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 554 µs ± 11.6 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 3.89 ms ± 144 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 583 µs ± 12.7 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 567 µs ± 17.9 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 4.76 ms ± 99.5 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 717 µs ± 12 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 562 µs ± 9.06 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 5.3 ms ± 38.5 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 810 µs ± 19.7 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 579 µs ± 10.4 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 6.25 ms ± 83.5 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 915 µs ± 9.7 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 566 µs ± 3.92 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 6.77 ms ± 59.2 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 1.02 ms ± 5.72 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 575 µs ± 4.78 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 7.47 ms ± 58.2 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 1.13 ms ± 6.21 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 583 µs ± 3.73 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 8.15 ms ± 53.7 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 1.25 ms ± 15.5 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 597 µs ± 8.18 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 8.92 ms ± 102 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 1.37 ms ± 19 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 602 µs ± 9.94 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 9.75 ms ± 195 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 1.47 ms ± 15.8 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 613 µs ± 5.17 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 10.4 ms ± 178 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 1.63 ms ± 60.6 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 662 µs ± 20.4 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 11.8 ms ± 145 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 1.79 ms ± 37.1 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 669 µs ± 11.1 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 12.4 ms ± 138 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 2.01 ms ± 65.2 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 663 µs ± 11 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 13.4 ms ± 290 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 2.08 ms ± 41.8 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 683 µs ± 15.4 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 13.9 ms ± 114 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 2.14 ms ± 43.4 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 703 µs ± 16.8 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 14.9 ms ± 340 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 2.21 ms ± 34.4 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 698 µs ± 10.8 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 15.6 ms ± 135 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 2.34 ms ± 24.6 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
fig, ax1 = plt.subplots(figsize=(15,8))

ax1.plot(n_rewires, ex_t[0,0], 's-b', label = 'C')
ax1.fill_between(n_rewires, ex_t[0,0]-ex_t[0,1], ex_t[0,0]+ex_t[0,1], color='b', alpha = .2)
#
ax1.plot(n_rewires, ex_t[1,0], 'r-s', label = 'Python')
ax1.fill_between(n_rewires, ex_t[1,0]-ex_t[1,1], ex_t[1,0]+ex_t[1,1], color='r', alpha = .2)
#
ax1.plot(n_rewires, ex_t[2,0], 'm-s', label = 'Python (numba)')
ax1.fill_between(n_rewires, ex_t[2,0]-ex_t[2,1], ex_t[2,0]+ex_t[2,1], color='m', alpha = .2)
#
plt.xlabel(r'$n_{\rm rewires}$', fontsize=15)
plt.ylabel('time [ms]', fontsize=15)
plt.title('Execution time', fontsize=15)
plt.legend()
# Inset 
left, bottom, width, height = [0.25, 0.6, 0.2, 0.2]
ax2 = fig.add_axes([left, bottom, width, height])
ax2.plot(n_rewires, ex_t[0,0], 's-b')
plt.title('Algorithm in C')
ax2.fill_between(n_rewires, ex_t[0,0]-ex_t[0,1], ex_t[0,0]+ex_t[0,1], color='b', alpha = .2)
#
ax2.plot(n_rewires, ex_t[2,0], 's-m')
plt.title('C and Numba')
ax2.fill_between(n_rewires, ex_t[2,0]-ex_t[2,1], ex_t[2,0]+ex_t[2,1], color='m', alpha = .2)
